# %%
expenses = [500,1200,300,800,2000]
expensive = []
for expense in expenses:
    if expense > 1000:
        expensive.append(expense)
print(expensive)
# Out:
# [1200, 2000]

# %%
def expensive_expenses(expenses):
    expenses = [500,1200,300,2000]
    result= []
    for expense in expensive_expenses:
        if expense > 1000:
            result.append(expenses)
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 7
#       5         if expense > 1000:
#       6             result.append(expenses)
# ----> 7 print(result)
#
# NameError: name 'result' is not defined

# %%
def expensive_expenses(expenses):
    result = []

    for expense in expenses:
        if expense > 1000:
            result.append(expense)
    return result
expenses =[500,1200,300,2000]
result = expensive_expenses(expenses)
print(result)
# Out:
# [1200, 2000]

# %%
def expensive_expenses(expenses):
    result = []
    total  = 0
    for expense in expenses:
        if expense>1000:
            result.append(expense)
    total = result + total
    print(toral)
expenses =[500,1200,300,2000]
result = expensive_expenses(expenses)
print(total)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 10
#       8     print(toral)
#       9 expenses =[500,1200,300,2000]
# ---> 10 result = expensive_expenses(expenses)
#      11 print(total)
#
# Cell In[26], line 7, in expensive_expenses(expenses)
#       5     if expense>1000:
#       6         result.append(expense)
# ----> 7 total = result + total
#       8 print(toral)
#
# TypeError: can only concatenate list (not "int") to list

# %%
def total_expensive_expenses(expenses):
    total = 0 
    for expense in expenses:
        if expense > 1000:
            total = total + expense
    return total
expenses = [500, 1200, 300, 2000,1500]
result = total_expensive_expenses(expenses)
print(result)
# Out:
# 4700

# %%
expenses = [500,1200,300,2000,1500]
largest =expenses[0]
for expense in expenses:
    if expense > largest:
        largest = expense
print(largest)
# Out:
# 2000

# %%
expenses = [500,1200,300,2000,1500,700,2500]
def count_expensive_expenses(expenses):
    for expense in count_expensive_expenses:
        count = 0
        if expenses > count:
    return count
# Out:
#   Cell In[35], line 6
#     return count
#     ^
# IndentationError: expected an indented block after 'if' statement on line 5

# %%
def count_expensive_expenses(expenses):
    count =0

    for expense in expenses:
        if expense > 1000:
            count +=1

    return count
expenses = [500,1200,300,2000,1500,700,2500]
result = count_expensive_expenses(expenses)
print(result)
# Out:
# 4

# %%
def fun
