# %%
#dictionary 
student = {
    "name" : "Rahul",
    "age" : 20,
    "marks": 85
}
print(student["name"])
print(student["age"])

student["city"] = "Delhi"
print(student["city"])

print(student["marks"])
student.keys()
student.values()
student.items()
# Out:
# Rahul
# 20
# Delhi
# 85
# dict_items([('name', 'Rahul'), ('age', 20), ('marks', 85), ('city', 'Delhi')])

# %%
expenses = {
    "food": 500,
    "travel":1000,
    "shopinng":2000
}
for key, value in expenses.items():
    print(key,value)
# Out:
# food 500
# travel 1000
# shopinng 2000

# %%
expenses = {
    "food": 500,
    "travel": 1000,
    "shopping": 2000
}
expenses["food"] = 800

expenses["medical"] = 700
print(expenses)
# Out:
# {'food': 800, 'travel': 1000, 'shopping': 2000, 'medical': 700}

# %%
student = {
    "name": "Rahul",
    "age": 20,
    "marks":75
}
student["marks"] = 90
student["city"] = "Delhi"
print(student)
# Out:
# {'name': 'Rahul', 'age': 20, 'marks': 90, 'city': 'Delhi'}

# %%
#Dictionary se Delete karna 
student = {
    "name": "Rahul",
    "age": 20,
    "marks":75,
    "city": "Delhi"
}
#ae delet karne ke liye hota hai 
del student["age"]
print(student)
# Out:
# {'name': 'Rahul', 'marks': 75, 'city': 'Delhi'}

# %%
#Dictionary se Delete karna 
student = {
    "name": "Rahul",
    "age": 20,
    "marks":90,
    "city": "Delhi"
}
#ae delet karne ke liye hota hai 
del student["age"]
print(student)
# Out:
# {'name': 'Rahul', 'marks': 90, 'city': 'Delhi'}

# %%
student = {
    "name": "Rahul",
    "age": 20,
    "marks":90,
    "city": "Delhi"
}
print(student.keys())
print(student.values())
print(student.items())

for key, value in student.items():
    print(key ,value)
# Out:
# dict_keys(['name', 'age', 'marks', 'city'])
# dict_values(['Rahul', 20, 90, 'Delhi'])
# dict_items([('name', 'Rahul'), ('age', 20), ('marks', 90), ('city', 'Delhi')])
# name Rahul
# age 20
# marks 90
# city Delhi

# %%
expenses = {
    "food": 500,
    "travel": 1000,
    "shopping":2000
}
for key, value in expenses.items():
    print(key, value)
# Out:
# food 500
# travel 1000
# shopping 2000

# %%
expenses = {
    "food": 500,
    "travel": 1000,
    "shopping":2000
}
for key, value in expenses.items():
    expense = []
    if expenses <= expense:
        expenses = expense
    else:
        print(key, value)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 8
#       6 for key, value in expenses.items():
#       7     expense = []
# ----> 8     if expenses <=expense:
#       9         expenses = expense
#      10     else:
#
# TypeError: '<=' not supported between instances of 'dict' and 'list'

# %%
expenses = {
    "food": 500,
    "travel": 1000,
    "shopping":2000
}

for key, value in expenses.items():
    if value > 1000:
        print(key, value)
# Out:
# shopping 2000

# %%
student = {
    "name": "Rahul",
    "marks": 90
}

print(student["age"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 6
#       1 student = {
#       2     "name": "Rahul",
#       3     "marks": 90
#       4 }
# ----> 6 print(student["age"])
#
# KeyError: 'age'

# %%
student = {
    "name": "Rahul",
    "marks": 90
}

print(student.get("age"))
# Out:
# None

# %%
student = {
    "name": "Rahul",
    "marks": 90
}
print(student.get("age",0))
# Out:
# 0
