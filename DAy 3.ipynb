# %%
print("Welcome to ticket counter ")
age = int(input("Enter your age :"))
if age <5:
    print("Free Ticket")
elif age <= 17:
    print("$100")
elif age >= 18:
    print("$200")
elif age <= 59:
    print("$200")
else:
    print("YOu are Senior Citizen 50$")
# Out:
# Welcome to ticket counter
# Enter your age : 17
# $100

# %%
print("Welcome to ticket counter ")
age = int(input("Enter your age: "))

if age < 5:
    print("Free Ticket")
elif age <= 17:
    print("$100")
elif age <= 59:
    print("$200")
else:
    print("You are a Senior Citizen: $50")
# Out:
# Welcome to ticket counter
# Enter your age:  19
# $200

# %%
# Out:
# Welcome to my school
# enter your marks  40
# B Grade

# %%
print("Welcome to my school")
marks = int(input("enter your marks "))

if marks > 90:
    print("A grade")
elif marks >= 80:
    print("B Grade")
elif marks >= 70:
    print("C Grade")
elif marks >= 60:
    print("D Grade")
else:
    print("Fail")
# Out:
# Welcome to my school
# enter your marks  99
# A grade

# %%
print("Welcome to Password Strength checker")
set_password = int(input("Enter your new password"))
if set_password < 8:
    print("weak password")
elif set_password >= 8:
    print("stonge Password")
# Out:
# Welcome to Password Strength checker
# Enter your new password 4
# weak password

# %%
print("-------------------")
num1 = int(input("enter your number "))
num2 = int(input("enter your number "))
num3 = int(input("enter your number "))

if num1 > 1000:
    print("Largest NUmber ")
elif num2 <1000:
    print("samll number")
elif num3 > 100000:
    print("very big number ")
else:
    print("Erro 411")
# Out:
# -------------------
# enter your number  40000
# enter your number  2000
# enter your number  200
# Largest NUmber

# %%
running = True
while running:
    print("Hello world")

    running = false
# Out:
# Hello world
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 5
#       2 while running:
#       3     print("Hello world")
# ----> 5     running = false
#
# NameError: name 'false' is not defined

# %%
running = True

while running:
    print("===calculator===")
    print(" 1 addition")
    print("2 subtraction")
    print("3 Multiplication")
    print("4 Divison")
    print("5 Exit")
    choosoption = int(input("Enter your option number?"))
    if choosoption == 1:
        num1 = int(input("enter your number 1 ?"))
        num2 = int(input("enter your number 2 ?"))
        add = num1+num2
        print(f"addtion : {add} ")
    elif choosoption == 2:
        num1 = int(input("enter your number 1 ?"))
        num2 = int(input("enter your number 2 ?"))
        sub = num1 - num2
        print(f"subtraction : {sub} ")
    elif choosoption == 3:
        num1 = int(input("enter your number 1 ?"))
        num2 = int(input("enter your number 2 ?"))
        mul = num1*num2
        print(f"multiplication: {mul} ")
    elif choosoption == 4:
        num1 = int(input("enter your number 1 ?"))
        num2 = int(input("enter your number 2 ?"))
        div = num1/num2
        div2 = num1/num2
        print(f"Divion : {div} ak aru hai  divsion {div2} ")
    elif choosoption == 5:
        print("Thank you for visit my calculatro sofware")
        running = False
    else:
        print("Inviled option")
# Out:
# ===calculator===
#  1 addition
# 2 subtraction
# 3 Multiplication
# 4 Divison
# 5 Exit
# Enter your option number? 9
# Inviled option
# ===calculator===
#  1 addition
# 2 subtraction
# 3 Multiplication
# 4 Divison
# 5 Exit
# Enter your option number? 10
# Inviled option
# ===calculator===
#  1 addition
# 2 subtraction
# 3 Multiplication
# 4 Divison
# 5 Exit
# Enter your option number? 5
# Thank you for visit my calculatro sofware

# %%
running = True
while running:
    print("="*30)
    running = False

# %%
# virion 03 
running = True
while running:
    print("="*50)
    print("  MY CALCULATOR")
    print("="*50)
    print(" 1 Addition")
    print("2 subtraction")
    print("3 Multiplication")
    print("4 Divison")
    print("5 Exit")
    choice = int(input("Choose Option: "))
    print("#"*50)
    if choice == 1:
        num1 = int(input("First Number : "))
        num2 = int(input("Second Number : "))
        print("Answer = ", num1 + num2)
        print("#"*50)
    elif choice == 2:
        num1 = int(input("First Number :"))
        num2 = int(input("Second Number : "))
        print("Answer = ", num1 - num2)
        print("#"*50)
    elif choice == 3:
        num1= int(input("First number :"))
        num2 = int(input("Second Number :"))
        print("Answer = ", num1*num2)
        print("#"*50)
    elif choice == 4:
        num1= int(input("First number :"))
        num2 = int(input("Second Number :"))
        print("Answer = ", num1/num2)
        print("#"*50)
    elif choice == 5:
        print("Thank you for visit my calculatro sofware")
        print("#"*50)
        running = False
    else:
        print("Inviled option")
# Out:
# ...
#   MY CALCULATOR
# ...
#  1 Addition
# 2 subtraction
# 3 Multiplication
# 4 Divison
# 5 Exit
# Choose Option:  2
# ##################################################
# First Number : 7
# Second Number :  7
# Answer =  0
# ##################################################
# ...
#   MY CALCULATOR
# ...
#  1 Addition
# 2 subtraction
# 3 Multiplication
# 4 Divison
# 5 Exit
# Choose Option:  5
# ##################################################
# Thank you for visit my calculatro sofware
# ##################################################

# %%
# new veresion 4

while True:
    print("Menu")
    print("="*50)
    print("  MY CALCULATOR")
    print("="*50)
    print(" 1 Addition")
    print("2 subtraction")
    print("3 Multiplication")
    print("4 Divison")
    print("5 Exit")
    print("#"*50)
    choice = int(input("Choose Option: "))
    if  choice == 5:
        break
print("program End")
# Out:
# Menu
# ...
#   MY CALCULATOR
# ...
#  1 Addition
# 2 subtraction
# 3 Multiplication
# 4 Divison
# 5 Exit
# ##################################################
# Choose Option:  5
# program End

# %%
# virion 03 

while True:
    print("Menu")
    print("="*50)
    print("  MY CALCULATOR")
    print("="*50)
    print(" 1 Addition")
    print("2 subtraction")
    print("3 Multiplication")
    print("4 Divison")
    print("5 Exit")
    print("="*50)
    choice = int(input("Choose Option: "))
    
    if choice == 1:
        num1 = int(input("First Number : "))
        num2 = int(input("Second Number : "))
        print("Answer = ", num1 + num2)
        print("-"*50)
    elif choice == 2:
        num1 = int(input("First Number :"))
        num2 = int(input("Second Number : "))
        print("Answer = ", num1 - num2)
        print("-"*50)
    elif choice == 3:
        num1= int(input("First number :"))
        num2 = int(input("Second Number :"))
        print("Answer = ", num1*num2)
        print("-"*50)
    elif choice == 4:
        num1= int(input("First number :"))
        num2 = int(input("Second Number :"))
        print("Answer = ", num1/num2)
        print("-"*50)
    elif choice == 5:
        print("Thank you ")
        print("-"*50)
        break
    else:
        print("Inviled option")
# Out:
# Menu
# ...
#   MY CALCULATOR
# ...
#  1 Addition
# 2 subtraction
# 3 Multiplication
# 4 Divison
# 5 Exit
# ...
# Choose Option:  5
# Thank you
# --------------------------------------------------

# %%
# continue

while True:
    num = int(input("Enter Number : "))

    if num < 0:
        continue
    print(num)
# Out:
# Enter Number :  10
# 10
# Enter Number :  -5
# Enter Number :  20
# 20
# Enter Number :  7787979
# 7787979
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 # continue
#       3 while True:
# ----> 4     num = int(input("Enter Number : "))
#       6     if num < 0:
#       7         continue
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1275, in Kernel.raw_input(self, prompt)
#    1273     msg = "raw_input was called, but this frontend does not support input requests."
#    1274     raise StdinNotImplementedError(msg)
# -> 1275 return self._input_request(
#    1276     str(prompt),
#    1277     self._parent_ident["shell"],
#    1278     self.get_parent("shell"),
#    1279     password=False,
#    1280 )
#
# ...
