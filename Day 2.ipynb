# %%
x = 10
y = 10
print(id(x))
print(id(y))
# Out:
# 140726877988040
# 140726877988040

# %%
x = 10
x = y
print(id(x))
print(id(y))
# Out:
# 140726877988040
# 140726877988040

# %%
x =10
x = y 
print(id(x))
print(id(y))
x = 20
print(id(x))
print(id(y))
# Out:
# 140726877988040
# 140726877988040
# 140726877988360
# 140726877988040

# %%
x = 5
x = x+1
print(id(x))
print(x)
# Out:
# 140726877987912
# 6

# %%
x = 5
x = y
x = x +5
print(id(x))
print(id(y))
print(x)
print(y)
# Out:
# 140726877988200
# 140726877988040
# 15
# 10

# %%
a = 5
b = a
a = a+5
print(a)
print(b)
# Out:
# 10
# 5

# %%
name ="vikash"
friend = name
name = "rohit"

print(name)
print(friend)
# Out:
# rohit
# vikash

# %%
x = 10
y = x
x = 5

print(y)
# Out:
# 10

# %%
balance = 2000
amount = int(input("enter your balance:"))
if balance < amount:
    print("Insufficient Balance")
else:
    print("Transaction Successful")
# Out:
# enter your balance: 200
# Transaction Successful

# %%
username = "vikash"
password = 1234
username1= input("Enter your user name ")
password1 = int(input("enter your password"))
if username == username1:
    print("login Successful")
else:
    print("Invalid Username or Password")
# Out:
# Enter your user name  vll
# enter your password 124
# Invalid Username or Password

# %%
print("Welcome to MY Calculator--------------------------------------- ")
print("----------------------------------------------------------------------------------")
print(" 1 addtion")
print(" 2 subration")
print("3 multiplication")
print("4 divison")
print("5 Exit")
print("--------------------------------------------------------------------------------")
chooseoption = int(input("chosse option : 1 , 2, 3 ,4 , 5"))
print("==================================================")
if chooseoption == 1:
    num1 = int(input("enter your number1?"))
    num2 = int(input("enter your number2?"))
    add = num1+num2
    print(f"Add ho gaya hai {add} ")
print("======================================================")
if chooseoption == 2:
    num1 = int(input("enter your number1?"))
    num2 = int(input("enter your number2?"))
    sub = num1-num2
    print(f"subtraction ho gaya {sub} hai")
print("===================================================")

if chooseoption == 3:
    num1 = int(input("enter your number1?"))
    num2 = int(input("enter your number2?"))
    mul = num1*num2
    print(f"multiplication ho gaya hai {mul} ")
print("===============================================")

if chooseoption == 4:
    num1 = int(input("enter your number1?"))
    num2 = int(input("enter your number2?"))
    div = num1/num2
    print(f" ae raha apka divsion kya huaa number {div}")
print("===============================================")

if chooseoption == 5:
    print("exit")
    breck
# Out:
# Welcome to MY Calculator---------------------------------------
# ----------------------------------------------------------------------------------
#  1 addtion
#  2 subration
# 3 multiplication
# 4 divison
# 5 Exit
# --------------------------------------------------------------------------------
# chosse option : 1 , 2, 3 ,4 , 5 4
# ...
# enter your number1? 4
# enter your number2? 4
#  ae raha apka divsion kya huaa number 1.0
# ...
