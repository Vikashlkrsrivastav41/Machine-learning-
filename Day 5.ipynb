# %%
students = ["vikash kumar ", "Rahul ", "aman"]
print(students)
# Out:
# ['vikash kumar ', 'Rahul ', 'aman']

# %%
import numpy

# %%
students = ["vikash kumar ", "Rahul ", "aman"]
print(students)
print(students[0])
# Out:
# ['vikash kumar ', 'Rahul ', 'aman']
# vikash kumar

# %%
students = ["vikash","Rahul","Aman"]
students[1]  = "Rohit"
students.append("Sohan")
print(students)
# Out:
# ['vikash', 'Rohit', 'Aman', 'Sohan']

# %%
#Dictionary Solution 
student = {
    "name": "Vikash",
    "age": 20,
    "marks": 95
}
student["city"] = "Patna"
print(student["name"])
print(student["age"])
print(student)
# Out:
# Vikash
# 20
# {'name': 'Vikash', 'age': 20, 'marks': 95, 'city': 'Patna'}

# %%
#Tuple 
days = (
    "Monday"
    "Tuesday",
    "Wednesday"
)

# %%
#set 
numbers = {1 ,2,3,3,4,4,5}
print(numbers)
# Out:
# {1, 2, 3, 4, 5}

# %%
labels = {
    "cat",
    "dog",
    "cat",
    "dog",
    "bird"
}

print(labels)
labels.add("fish")
print(labels)
labels.remove("dog")
print(labels)
# Out:
# {'dog', 'cat', 'bird'}
# {'dog', 'fish', 'cat', 'bird'}
# {'fish', 'cat', 'bird'}

# %%
file = open("student.txt", "w")
file.write("Vikash")
file.close()

# %%
file = open("student.txt", "r")
data = file.read()
print(data)
# Out:
# rahul

# %%
file = open("student.txt","w")
data = file.write("rahul")
print(data)
# Out:
# 5

# %%
file = open("student.txt", "a")
file.write("\nSohan")
print(data)
file.close()
# Out:
# rahul

# %%
print(data)
# Out:
# rahul

# %%
file = open("student.txt","r")

for line in file:
    print(line)
file.close()
# Out:
# rahul
#
# Sohan
#
# Sohan
#
# Sohan

# %%
with open("student.txt", "r") as file:
    data = file.read()
print(data)
# Out:
# rahul
# Sohan
# Sohan
# Sohan

# %%
with open("student.txt", "w") as file:
    file.write("Python\n")
    file.write("AI\n")
    file.write("LLM\n")

# %%
with open("student.txt", "r") as file:
    data = file.read()
print(data)
# Out:
# Python
# AI
# LLM
