# %%
# python me vector 
x = [2,3,4]
print(x)
print(x[0])
print(x[0])
print(x[1])
# Out:
# [2, 3, 4]
# 2
# 2
# 3

# %%
import numpy as np 
x = np.array([2,3,4])
print(x)
print(x+2)
# Out:
# [2 3 4]
# [4 5 6]

# %%
import numpy as np
x = np.array([2,3])

weights = np.array([0.5,0.8])
bias = 1
output = np.dot(x,weights)+bias
print(output)
# Out:
# 4.4
