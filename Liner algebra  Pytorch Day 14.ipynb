# %%
import torch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import torch
#
# ModuleNotFoundError: No module named 'torch'

# %%
# !pip install torch
# Out:
# Collecting torch
#   Downloading torch-2.13.0-cp313-cp313-win_amd64.whl.metadata (39 kB)
# Requirement already satisfied: filelock in c:\users\hp\anaconda3\lib\site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\hp\anaconda3\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools>=77.0.3 in c:\users\hp\anaconda3\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\hp\anaconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\hp\anaconda3\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\hp\anaconda3\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\hp\anaconda3\lib\site-packages (from torch) (2025.10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\hp\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\anaconda3\lib\site-packages (from jinja2->torch) (3.0.2)
# Downloading torch-2.13.0-cp313-cp313-win_amd64.whl (122.1 MB)
#    ---------------------------------------- 0.0/122.1 MB ? eta -:--:--
#    ---------------------------------------- 1.0/122.1 MB 8.6 MB/s eta 0:00:15
#     --------------------------------------- 2.6/122.1 MB 7.8 MB/s eta 0:00:16
#    - -------------------------------------- 4.7/122.1 MB 9.3 MB/s eta 0:00:13
#    -- ------------------------------------- 7.1/122.1 MB 9.2 MB/s eta 0:00:13
#    -- ------------------------------------- 8.4/122.1 MB 9.2 MB/s eta 0:00:13
#    --- ------------------------------------ 10.0/122.1 MB 8.8 MB/s eta 0:00:13
#    ---- ----------------------------------- 12.3/122.1 MB 8.9 MB/s eta 0:00:13
#    ---- ----------------------------------- 14.7/122.1 MB 9.1 MB/s eta 0:00:12
#    ----- ---------------------------------- 18.1/122.1 MB 9.8 MB/s eta 0:00:11
#    ------- -------------------------------- 21.8/122.1 MB 10.8 MB/s eta 0:00:10
#    -------- ------------------------------- 26.0/122.1 MB 11.4 MB/s eta 0:00:09
#    -------- ------------------------------- 26.2/122.1 MB 11.4 MB/s eta 0:00:09
#    --------- ------------------------------ 29.9/122.1 MB 11.1 MB/s eta 0:00:09
#    ---------- ----------------------------- 32.5/122.1 MB 11.2 MB/s eta 0:00:08
#    ----------- ---------------------------- 36.4/122.1 MB 11.6 MB/s eta 0:00:08
#    ------------ --------------------------- 39.3/122.1 MB 11.7 MB/s eta 0:00:08
#    ------------- -------------------------- 42.5/122.1 MB 11.9 MB/s eta 0:00:07
#    -------------- ------------------------- 45.1/122.1 MB 12.1 MB/s eta 0:00:07
#    --------------- ------------------------ 47.2/122.1 MB 11.8 MB/s eta 0:00:07
#    ---------------- ----------------------- 49.3/122.1 MB 11.7 MB/s eta 0:00:07
#    ----------------- ---------------------- 52.2/122.1 MB 11.8 MB/s eta 0:00:06
#    ------------------ --------------------- 55.1/122.1 MB 11.9 MB/s eta 0:00:06
#    ------------------ --------------------- 57.7/122.1 MB 11.8 MB/s eta 0:00:06
#    ------------------- -------------------- 60.8/122.1 MB 11.9 MB/s eta 0:00:06
#    -------------------- ------------------- 62.9/122.1 MB 11.8 MB/s eta 0:00:06
#    --------------------- ------------------ 65.0/122.1 MB 11.8 MB/s eta 0:00:05
#    ---------------------- ----------------- 67.6/122.1 MB 11.8 MB/s eta 0:00:05
#    ----------------------- ---------------- 70.8/122.1 MB 11.9 MB/s eta 0:00:05
#    ------------------------ --------------- 74.4/122.1 MB 12.1 MB/s eta 0:00:04
#    ------------------------- -------------- 77.6/122.1 MB 12.1 MB/s eta 0:00:04
#    -------------------------- ------------- 80.0/122.1 MB 12.1 MB/s eta 0:00:04
#    -------------------------- ------------- 82.3/122.1 MB 12.0 MB/s eta 0:00:04
#    --------------------------- ------------ 84.4/122.1 MB 12.0 MB/s eta 0:00:04
#    ---------------------------- ----------- 87.6/122.1 MB 12.1 MB/s eta 0:00:03
#    ----------------------------- ---------- 90.7/122.1 MB 12.2 MB/s eta 0:00:03
#    ------------------------------ --------- 94.1/122.1 MB 12.3 MB/s eta 0:00:03
#    ------------------------------- -------- 95.4/122.1 MB 12.2 MB/s eta 0:00:03
#    ------------------------------- -------- 96.7/122.1 MB 11.9 MB/s eta 0:00:03
#    -------------------------------- ------- 98.6/122.1 MB 11.9 MB/s eta 0:00:02
#    -------------------------------- ------ 101.7/122.1 MB 11.9 MB/s eta 0:00:02
#    --------------------------------- ----- 104.6/122.1 MB 12.0 MB/s eta 0:00:02
#    ---------------------------------- ---- 108.0/122.1 MB 12.0 MB/s eta 0:00:02
#    ----------------------------------- --- 111.1/122.1 MB 12.1 MB/s eta 0:00:01
#    ------------------------------------ -- 113.0/122.1 MB 12.1 MB/s eta 0:00:01
#    ------------------------------------ -- 115.1/122.1 MB 12.1 MB/s eta 0:00:01
#    ------------------------------------- - 117.7/122.1 MB 12.0 MB/s eta 0:00:01
#    --------------------------------------  120.6/122.1 MB 12.0 MB/s eta 0:00:01
#    --------------------------------------  121.9/122.1 MB 12.0 MB/s eta 0:00:01
#    --------------------------------------  121.9/122.1 MB 12.0 MB/s eta 0:00:01
#    ---------------------------------------- 122.1/122.1 MB 11.4 MB/s  0:00:10
# Installing collected packages: torch
# Successfully installed torch-2.13.0

# %%
import torch

# %%
print(torch.__version__)
# Out:
# 2.13.0+cpu

# %%
import torch 
x = torch.tensor(2.0,requires_grad=True)

y = x**2

y .backward()
print(x.grad)
# Out:
# tensor(4.)

# %%
import numpy as np
x = np.array([1,2,3])
print(x)
# Out:
# [1 2 3]

# %%
import torch
x = torch.tensor([1,2,3])
print(x)
# Out:
# tensor([1, 2, 3])

# %%
x = torch.tensor(5)
x.ndim # ika koi dimensioon nahi hai hai
# Out:
# 0

# %%
x = torch.tensor([1,2,3])
x.shape
x.ndim
# Out:
# 1

# %%
x.ndim
# Out:
# 1

# %%
#do  dimenshions matrix function 
x = torch.tensor([
    [1,2],
    [3,4]
])
x.shape
x.ndim
# Out:
# 2

# %%
#higher-dimensional Tensor
x = torch.tensor([
    [[1,2] , [3,4]],
    [[5,6] , [7,8]]
])
x.shape
# Out:
# torch.Size([2, 2, 2])

# %%
x = torch.tensor([
    [1,2,3],
    [4,5,6]
])
x.shape
# Out:
# torch.Size([2, 3])

# %%
x = torch.tensor([1,2,3])
print(x.dtype)
# Out:
# torch.int64

# %%
import numpy as np
x = np.array([1. ,2.,3.])

print(x.shape)
print(x.ndim)
print(x.dtype)
# Out:
# (3,)
# 1
# float64

# %%
import torch
x = torch.tensor([1. ,2.,3.])
print(x.shape)
print(x.ndim)
print(x.dtype)
# Out:
# torch.Size([3])
# 1
# torch.float32
