# %%
expenses = [500,1200,300,800,2000]

for expens in expenses:
    if expens > 1000:
        print(expens)
# Out:
# 1200
# 2000

# %%
expenses = [500,1200,300,800,2000]
total = 0

for expense in expenses:
    total = total + expense
print(total)
# Out:
# 4800

# %%
expenses = []
expense = int(input("enter expense:"))
expenses.append(expense)
print(expenses)
# Out:
# enter expense: 10
# [10]

# %%
# dot't run your code in python
expenses = []
while True:
    expense = int(input("enter expense:"))
    expenses.append(expense)
    more = input("enter more expense? (yes/no):")
    if more == "no":
        break
print(expenses)
# Out:
# enter expense: 20
# enter more expense? (yes/no): yes
# enter expense: 40
# enter more expense? (yes/no): yes
# enter expense: 50
# enter more expense? (yes/no): yes
# enter expense: 50
# enter more expense? (yes/no): no
# [20, 40, 50, 50]
