# %%
# %%writefile calculator.py 
def add(a,b):
    return a+b
def subtract(a,b):
    return a-b
# Out:
# Writing calculator.py

# %%
import os 
print(os.listdir())
# Out:
# ['.anaconda', '.astropy', '.cache', '.conda', '.config', '.continuum', '.copilot', '.gitconfig', '.ipynb_checkpoints', '.ipython', '.jupyter', '.lesshst', '.lightkurve', '.matplotlib', '.virtual_documents', '.vscode', '.vscode-shared', '1744645887159-10_lists.ipynb', 'anaconda3', 'anaconda_projects', 'AppData', 'Application Data', 'AYUSH .ipynb', 'calculator', 'calculator.py', 'Contacts', 'Cookies', 'CrossDevice', 'DAy 11 Memory lock .ipynb', 'DAy 11 Nerul network .ipynb', 'day 11.ipynb', 'DAy 12 .ipynb', 'Day 13 Liner algebra .ipynb', 'Day 13 Menory unlock .ipynb', 'day 13 numpy .ipynb', 'DAy 14 Python Dictionary  .ipynb', 'Day 2.ipynb', 'DAy 3.ipynb', 'DAy 4.ipynb', 'Day 5.ipynb', 'Day 7.ipynb', 'Day 8.ipynb', 'day 9.ipynb', 'Desktop', 'Documents', 'Downloads', 'Favorites', 'Linear Algebra day 01 day 11 code .ipynb', 'Links', 'Local Settings', 'Memory LOck Day 10 .ipynb', 'micrograd_from_scratch_yay.ipynb', 'Model & Packages python Day 14.ipynb', 'Music', 'My Documents', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{9a86cb17-3433-11f1-9d47-f9f9285d5833}.TM.blf', 'NTUSER.DAT{9a86cb17-3433-11f1-9d47-f9f9285d5833}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{9a86cb17-3433-11f1-9d47-f9f9285d5833}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'numpy .ipynb', 'Numpy day 11 01.ipynb', 'Nural network Day 13.ipynb', 'OneDrive', 'OOP and together .ipynb', 'PrintHood', 'Problem sloving  DAy 14 Python .ipynb', 'Recent', 'Saved Games', 'Searches', 'SendTo', 'Start Menu', 'student.txt', 'Templates', 'Videos', '__pycache__']

# %%
import calculator
print(calculator.add(10,5))
print(calculator.subtract(10,5))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 import calculator
# ----> 2 print(calculator.add(10,5))
#       3 print(calculator.subtract(10,5))
#
# AttributeError: module 'calculator' has no attribute 'add'

# %%
# %%writefile mycalculator.py
def add(a, b):
    return a+b
def subtract(a,b):
    return a-b
# Out:
# Writing mycalculator.py

# %%
import mycalculator

# %%
print(mycalculator.add(10, 5))
print(mycalculator.subtract(10, 5))
# Out:
# 15
# 5
