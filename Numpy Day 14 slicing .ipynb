# %%
import numpy as np 
marks = np.array ([45, 67, 89, 32, 95, 76])
marks[0]
# Out:
# np.int64(45)

# %%
marks = np.array ([45, 67, 89, 32, 95, 76])
marks[2]
# Out:
# np.int64(89)

# %%
marks = np.array([45,67,89,32,95,76])
marks[-1]
# Out:
# np.int64(76)

# %%
marks = np.array([45,67,89,32,95,76,54,88,91,39])
marks [2:6]
marks[marks > 70]
# Out:
# array([89, 95, 76, 88, 91])

# %%
# real problem 
sales =np.array([ 
    100,1500,900,1800,
    2100,1300,1700,800,
    2500,1600
])
sales[sales > 1500]
# Out:
# array([1800, 2100, 1700, 2500, 1600])

# %%
# Filtering + Calculation galsti hai 
sales =np.array([ 
    100,1500,900,1800,
    2100,1300,1700,800,
    2500,1600
])
sales [sales >1500]
sales = np.sum(sales)
print(sales )
# Out:
# 14300

# %%
sales =np.array([ 
    100,1500,900,1800,
    2100,1300,1700,800,
    2500,1600
])
np.sum(sales[sales>1500])
np.max(sales)
np.min(sales)
np.mean(sales[sales>1500:sales<2000])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 9
#       7 np.max(sales)
#       8 np.min(sales)
# ----> 9 np.mean(sales[sales>1500:sales<2000])
#
# TypeError: only integer scalar arrays can be converted to a scalar index
