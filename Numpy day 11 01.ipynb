# %%
import numpy as np

# %%
import numpy as np 
marks = [78,85,92,67,88]
arr = np.array(marks)
print(arr)
# Out:
# [78 85 92 67 88]

# %%
#normal python 
marks = [78,85,92,67,88]
new_marks = []
for x in marks:
    new_marks.append(x+5)
print(new_marks)
# Out:
# [83, 90, 97, 72, 93]

# %%
import numpy as np

marks =np.array([78,85,92,67,88])

new_marks = marks + 5

print(new_marks)
# Out:
# [83 90 97 72 93]
