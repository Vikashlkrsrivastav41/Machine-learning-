# %%
#one neuron
z = np.dot(w , x) +b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #one neuron
# ----> 2 z = np.dot(w , x) +b
#
# NameError: name 'np' is not defined

# %%
import numpy as np

x = np.array([2,4,3])

w = np.array([
    [0.5, 0.2,-0.4],
    [-0.3,0.8,0.1],
    [0.7,-0.2,0.5]
])

b = np.array([0.5,-0.2,0.1])
z = np.dot(w , x) +b
print(z)
# Out:
# [1.1 2.7 2.2]

# %%
x  =np.array([2,4,3])

w = np.array([
    [0.5, 0.2,-0.4],
    [-0.3,0.8,0.1],
    [0.7,-0.2,0.5]
])

b = np.array([0.5,-0.2,0.1])
z = np.dot(w , x) +b
a = 1/(1+np.exp(-z))
print(a)
print(z)
# Out:
# [0.75026011 0.93702664 0.90024951]
# [1.1 2.7 2.2]

# %%
w = np.array([
    [0.5, 0.2,-0.4],
    [-0.3,0.8,0.1],
    [0.7,-0.2,0.5]
])

x =  np.array([2 , 4,3])
b = np.array([0.5,-0.2,0.1])
z = np.dot(w,x) + b
a = 1/(1+np.exp(-z))
print(z)
print(a)
# Out:
# [1.1 2.7 2.2]
# [0.75026011 0.93702664 0.90024951]

# %%
import numpy as np
import math 
import pandas as pd
import pytorch as pt
import tensor
