# %%
class student:
    pass
s1 = student()
s2 = student()

print(s1)
print(s2)

# %%
class student:
    def __init__(self):
        print("Student Created ")
s1 = student()
# Out:
# Student Created

# %%
class Student:
    def __init__(self,name):
        self.name = name

s1 = Student("Rahul")
s2 = Student("vikash")

# %%
class student:
    def __init__(self,name,age):

        self.name = name
        self.age = age
s1 = student("Rahul", 20)
s2 = student("Vikash", 18)

print(s1.name)
print(s1.age)

print(s2.name)
print(s2.age)
# Out:
# Rahul
# 20
# Vikash
# 18

# %%
class Dog:
    def bark(self):
        print("Bow Bow ")
d = Dog()
d.bark()
# Out:
# Bow Bow

# %%
class Student:
    def __init__(self,name,age):
        
        self.name=name
        self.age=age
    def intro(self):
        print("Hello",self.name)
    def study(self):
        print(self.name,"is studying ")
    def age(self):
        print(self.age,"This is my age ")

s1 = Student("Rahul",20)
s1.age()
s1.intro()
s1.study()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 14
#      11         print(self.age,"This is my age ")
#      13 s1 = Student("Rahul",20)
# ---> 14 s1.age()
#      15 s1.intro()
#      16 s1.study()
#
# TypeError: 'int' object is not callable

# %%
class Bank:
    def __init__(self):
        self.balance =1000
b = Bank()
print(b.balance)
# Out:
# 1000

# %%
class Bank:
    def __init__(self):
        self.__balance = 2000
b = Bank()
print(b.__balance)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 5
#       3         self.__balance = 2000
#       4 b = Bank()
# ----> 5 print(b.__balance)
#
# AttributeError: 'Bank' object has no attribute '__balance'

# %%
class Bank:
    def __init__(self):
        self.__balance = 4000
    def show(self):
        print(self.__balance)
b = Bank()
print(b.show)
# Out:
# <bound method Bank.show of <__main__.Bank object at 0x00000210940DD550>>

# %%
class Father:
    def bike(self):
        print("hello honda")


print(Father)
# Out:
# <class '__main__.Father'>

# %%
class son(Father):
    def bike(self):

        print("Kawasaki Ninja ")
s = son()
s.bike()
# Out:
# Kawasaki Ninja

# %%
class age:
    def ask(self):
        if age >18:
            print("not elible")
        else:
            print("elgible")
s = age()
s.ask()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       6             print("elgible")
#       7 s = age()
# ----> 8 s.ask()
#
# Cell In[1], line 3, in age.ask(self)
#       2 def ask(self):
# ----> 3     if age >18:
#       4         print("not elible")
#       5     else:
#
# TypeError: '>' not supported between instances of 'type' and 'int'

# %%
age = int(input("Enter your age:"));

if age < 18:
    print("not elijible hai");
else:
    print("elijible hai ");
# Out:
# Enter your age: 15
# not elijible hai

# %%
x = 10
y = 40


print(id(x))
print(id(y))
# Out:
# 140719189894344
# 140719189895304

# %%
a = 1000
b = 2000

print(id(a))
print(id(b))
# Out:
# 1572778025104
# 1572778030864

# %%
name ="rahul"
student_name = "rahul"
studentName = "Rahul"

# %%
print("Hello world Print karo")
# Out:
# Hello world Print karo

# %%
name = "vikash kumar"
print(name)
# Out:
# vikash kumar

# %%
age = 50
print(age)
# Out:
# 50

# %%
city = "patna"
countery = "India"
print(city)
print(countery)
# Out:
# patna
# India

# %%
name = str(input("enter your enter "));
age = int(input("enter your age "));

print("hello ji my name is ,name,and i age old")
# Out:
# enter your enter  4
# enter your age  44
# hello ji my name is ,name,and i age old

# %%
print("my name is vikash kumar and i 18 yers old boy")
# Out:
# my name is vikash kumar and i 18 yers old boy

# %%
print("hello world ")
# Out:
# hello world

# %%
name = input("enter your name :")
age = int(input("enter your age :"))
city = input("enter your city:")

print(f"Hello {name} you are {age}  years old. you live in {city}.")
# Out:
# enter your name : rohit
# enter your age : 41
# enter your city: patna
# Hello rohit you are 41  years old. you live in patna.

# %%
num1 = int(input("enter your first number :"));
num2 = int(input("enter your second number:"));
answer = num1+num2
answer2 = num1-num2
answer4 = num1*num2
answer3 = num1/num2

print(f"addition hia  {answer}")
print(f"subrraction hia {answer2}")
print(f"multiplication hai {answer3}")
print(f"division hai {answer4}")
# Out:
# enter your first number : 4
# enter your second number: 4
# answer hia  8
# answer hia 0
# answer hai 1.0
# answer hai 16

# %%
num1 = int(input("enter your first number :"));
num2 = int(input("enter your second number:"));
addition = num1+num2 
subtraction = num1-num2
Multiplication = num1*num2
division = num1/num2

print(f"addition = {addition}")
print(f"subtraction = {subtraction}")
print(f"multiplication = {Multiplication}")
print(f"division = {division}")
print("ho gaya na kaam ")
# Out:
# enter your first number : 4
# enter your second number: 4
# addition =8
# subtraction =0
# multiplication =16
# division = 1.0
# ho gaya na kaam

# %%
Length = 10
Width = 5
Area = Length*Width
print(f" yaha Area = {Area} hai ");
# Out:
#  yaha Area = 50 hai

# %%
length = 4
width = 4
area = length *width
print(f"Yaha Area {area} hai ")
# Out:
# Yaha Area 16 hai

# %%
length = int(input("length kitna hai "));
width = int(input("width kitna hai "));
area = length*width
print(f"Yaha Area {area} hai")
# Out:
# length kitna hai  4
# width kitna hai  4
# Yaha Area 16 hai

# %%
length = int(input("length kitna hai "));
width = int(input("width kitna hai "));
perimeter = 2*(length+width)

print(f"perimeter = {perimeter}")
# Out:
# length kitna hai  4
# width kitna hai  4
# perimeter = 16

# %%
length = int(input("Enter length:"))
width = int(input("Enter widthi:"))
area = length *width
perimeter= 2 *(length+width)
print(f"area =  {area} ");
print(f"perimeter = {perimeter} ");
# Out:
# Enter length: 4
# Enter widthi: 4
# area =  16
# perimeter = 16

# %%
originalprice = int(input("Enter original Price :"))
discount = int(input("Enter Discount ammount :"))
finalprice = originalprice - discount
print(f"Final price hai {finalprice}")
# Out:
# Enter original Price : 500
# Enter Discount ammount : 20%
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 2
#       1 originalprice = int(input("Enter original Price :"))
# ----> 2 discount = int(input("Enter Discount ammount :"))
#       3 finalprice = originalprice - discount
#       4 print(f"Final price hai {finalprice}")
#
# ValueError: invalid literal for int() with base 10: '20%'

# %%
name = "viaksh"
age =50

print(id(name))
print(id(age))
# Out:
# 2514795995776
# 140703627192776
