# %%
def add(a,b):
    return a+b

result = add(4,5)
print(result)
# Out:
# 9

# %%
def calculate_total(price, quantity):
    total = price * quantity
    return total
result = calculate_total(100,3)
print(result)
# Out:
# 300
