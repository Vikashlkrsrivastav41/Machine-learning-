# %%
import numpy as np

# %%
z = np.dot(w , x) +b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 z = np.dot(w , x) +b
#
# NameError: name 'w' is not defined

# %%
import numpy as np 
x = np.array ([ 2,4,3])


w = np.array([
    [0.5 , 0.2 , -0.4],
    [-0.3 , 0.8 , 0.1],
    [0.7,-0.2,0.5]
])


b = np.array([0.5,-0.2,0.1])
z = np.dot(w , x) +b
print(z)
# Out:
# [1.1 2.7 2.2]

# %%
x =np.array ([4,6,8])

w = np.array([
    [0.5, 0.6,-0.4],
    [-0.3,0.8,0.1],
    [0.7,-0.8,0.5]
])

#This is use of amount data nueorn network 




b = np.array([,-0.5,-0.9,0.7])
z = np.dot(w,x)+b
a = 1/(1+np.exp(-z))
print(a)
print(z)
# Out:
#   Cell In[4], line 14
#     b = np.array([,-0.5,-0.9,0.7])
#                   ^
# SyntaxError: invalid syntax

# %%
z = np.dot(w,x)+b
