# %%
# %%writefile calculator.py
def add(a,b):
    return a + b
def subtract(a,b):
    return a - b
# Out:
# Overwriting calculator.py

# %%
import calculator
import importlib

importlib.reload(calculator)

print(calculator.add(10, 5))
print(calculator.subtract(10, 5))
# Out:
# 15
# 5

# %%
# %%writefile basic.py
def add(a,b):
    return a+b
def subtract(a,b):
    return a -b
# Out:
# Writing basic.py

# %%
# %%writefile advanced.py
def multiply(a*b):
    return a*b
def subtract(a,b):
    return a-b
# Out:
# Writing advanced.py

# %%
def multiply(a,b):
    return a+b
def divide(a,b):
    return a / b

# %%
import os

os.makedirs("calculator", exist_ok=True)

# %%
# %%writefile calculator/basic.py
def add(a,b):
    return a+b
def subtract(a,b):
    return a-b
# Out:
# Writing calculator/basic.py

# %%
# %%writefile calculator/advanced.py
def multiply(a,b):
    return a*b
def divide(a,b):
    return  a/b
# Out:
# Overwriting calculator/advanced.py

# %%
# %%writefile calculator/__init__.py
# Empty init file
# Out:
# Writing calculator/__init__.py

# %%
import sys
import importlib

# Cache se purana calculator module hatane ke liye
if 'calculator' in sys.modules:
    del sys.modules['calculator']

from calculator.basic import add, subtract
from calculator.advanced import multiply, divide

print(add(10, 5))
print(subtract(10, 5))
print(multiply(10, 5))
print(divide(10, 5))
# Out:
# 15
# 5
# 50
# 2.0

# %%
def add_expenses(
