# %%
#python list
marks = [70,80,90,60, 100]

# %%
import numpy as np 
marks = np.array([70, 80,90,60,100])
total = np.sum(marks)
number = len(marks)
average = total/number
print(average)
# Out:
# 80.0

# %%
marks = np.array([70, 80,90,60,100])
highest = np.max(marks)
print(highest)
# Out:
# 100

# %%
import numpy as np 
marks = np. array ([45,78,92,66,81,55,73,88,95,61])
average = np.mean(marks)
print(average)
# Out:
# 73.4

# %%
import numpy as np
sales = np.array([1200,1500,900,1800,2100,1300,1700])
total  = np.sum(sales)
print(total)
average = np.mean(sales)
print(average)
highest = np.max(sales)
print(highest)
lowest = np.min(sales)
print(lowest)
print(sales[sales>1500])

total = np.sum(sales[sales>1500])
print(total)
# Out:
# 10500
# 1500.0
# 2100
# 900
# [1800 2100 1700]
# 5600

# %%
import numpy as np
marks = np.array([
    [80,70,90,60],
    [90,85,75,95],
    [70,80,65,75]
])
average = np.mean(marks,axis = 1)
print(average)
average = np.mean(marks,axis = 0)
print(average)
# Out:
# [75.   86.25 72.5 ]
# [80.         78.33333333 76.66666667 76.66666667]

# %%
import numpy as np
sales = np.array([
    1200,
    1500,
    900,
    1800,
    2100,
    1300,
    1700
])
total = np.sum(sales)
print(total)
average = np.mean(sales)
print(average)
highest = np.max(sales)
print(highest)
lowest = np.min(sales)
print(lowest)
# Out:
# 10500
# 1500.0
# 2100
# 900
