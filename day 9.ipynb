# %%
# %%writefile calculator.py
def add(a,b):
    return a+b
def multiply(a,b):
    return a*b
# Out:
# Writing calculator.py

# %%
import calculator
print(calculator.add(7,10))
print(calculator. multiply(5,4))
# Out:
# 17
# 20
