# %%
import torch

# %%
x = torch.tensor([1,2,3])
print(x)
# Out:
# tensor([1, 2, 3])

# %%
print(x.dtype)
# Out:
# torch.int64

# %%
x = torch.tensor([1,2,3])
print(x+10)
# Out:
# tensor([11, 12, 13])

# %%
print(x*10)
# Out:
# tensor([10, 20, 30])

# %%
print(x**2)
# Out:
# tensor([1, 4, 9])

# %%
import torch 
x = torch.tensor([2.,3.])
w = torch.tensor([0.5,0.8])
b = torch.tensor(1.)

z = torch.dot(w ,x ) + b

print(z)
# Out:
# tensor(4.4000)

# %%
x = torch.tensor([3. , 4.])
w = torch.tensor([0.2,0.7])
b = torch.tensor(2.)

a = torch.dot(w ,x ) +b 
print(a )
print(type(x))
print(x.shape)
print(x.ndim)
print(x.dtype)
# Out:
# tensor(5.4000)
# <class 'torch.Tensor'>
# torch.Size([2])
# 1
# torch.float32

# %%
12
